# %%
import pandas as pd

# df = pd.read_csv('Friends_A_vad.tsv', sep='\t')
df = pd.read_csv('CPED_A_VAD.tsv', sep='\t')
df.head()
# Out:
#   speaker  dialog_state                                      emotions  \
# 0     童文洁  [1, 1, 0, 1]  ['neutral', 'neutral', 'neutral', 'neutral']
# 1      刘静  [0, 0, 1, 0]  ['neutral', 'neutral', 'neutral', 'neutral']
# 2      刘静     [1, 0, 1]             ['neutral', 'neutral', 'neutral']
# 3     童文洁     [0, 1, 0]             ['neutral', 'neutral', 'neutral']
# 4     童文洁  [1, 1, 0, 1]  ['neutral', 'neutral', 'neutral', 'neutral']
#
#                                                 sent  \
# 0  ['what a coincidence', 'the car is fine', "It'...
# 1  ['what a coincidence', 'the car is fine', "It'...
# 2  ['right', 'Your kids go to school here too', '...
# 3  ['right', 'Your kids go to school here too', '...
# 4  ['What a coincidence my son is here', 'what gr...
#
#                                            utterance  \
# 0  what a coincidence the car is fine It's okay, ...
# 1          It's you, it's okay, it's okay, thank you
# 2                                          right Yes
# ...

# %%
df.shape
# Out:
# (23794, 14)

# %%
df_EmoBERTa = pd.DataFrame(EmoBERTa_labels)
df_EmoBERTa[0].value_counts()
# Out:
# neutral    6850
# joy         922
# anger       384
# sadness       1
# Name: 0, dtype: int64
